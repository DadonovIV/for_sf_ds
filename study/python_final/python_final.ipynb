# %%
import pandas as pd

solar_data = pd.read_csv('C:/Users/ilyad/IDE/study/python_final/solarpower.csv')
solar_data
# Out:
#            date  cum_power
# 0    2017-01-01    20111.0
# 1    2017-01-02    20112.0
# 2    2017-01-03    20115.0
# 3    2017-01-04    20117.0
# 4    2017-01-05    20119.0
# ..          ...        ...
# 659  2018-10-22    28101.0
# 660  2018-10-23    28109.0
# 661  2018-10-24    28115.0
# 662  2018-10-25    28117.0
# 663  2018-10-26    28120.0
#
# [664 rows x 2 columns]

# %%
df = pd.DataFrame(solar_data)

date_cols = ["date"]
df[date_cols] = df[date_cols].astype("datetime64[ns]")
df["day_power"] = df["date"].dt.to_period("M")
df
# Out:
#           date  cum_power day_power
# 0   2017-01-01    20111.0   2017-01
# 1   2017-01-02    20112.0   2017-01
# 2   2017-01-03    20115.0   2017-01
# 3   2017-01-04    20117.0   2017-01
# 4   2017-01-05    20119.0   2017-01
# ..         ...        ...       ...
# 659 2018-10-22    28101.0   2018-10
# 660 2018-10-23    28109.0   2018-10
# 661 2018-10-24    28115.0   2018-10
# 662 2018-10-25    28117.0   2018-10
# 663 2018-10-26    28120.0   2018-10
#
# [664 rows x 3 columns]

# %%
df["day_power"]['2017-03'] = df.mean(axis=2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\ilyad\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     575             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     576         except KeyError:
# --> 577             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 2
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20360\177097541.py in ?()
# ----> 1 df["day_power"]['2017-03'] = df.mean(axis=2)
#
# c:\Users\ilyad\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py in ?(self, axis, skipna, numeric_only, **kwargs)
#   11676         skipna: bool = True,
#   11677         numeric_only: bool = False,
# ...
